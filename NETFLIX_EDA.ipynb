# %% [markdown]
# <a href="https://colab.research.google.com/github/Sha2810k/Netflix-EDA/blob/main/NETFLIX_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![_Pandemie__ Netflix-Serie schwankt zwischen Panikmache und Aufklärung _ Kritik.jpeg](data:image/jpeg;base64,...)

# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df=pd.read_csv("/content/Project+8+-+Netflix+Dataset.csv")

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # BASIC INFO ABOUT DATASET
#
# ---

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# # CHECKING DUPLICATE RECORDS
#
# ---

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates()
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# # CHECK NULL VALUES
#
# ---

# %%
df.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# # **# For 'The Outsiders', what is the Show Id and Who is the Director of this show ?**
#
#
# ---

# %%
df[df['Title'].isin(['The Outsiders'])]
# Out:
#      Show_Id Category          Title Director  \
# 6738   s6737  TV Show  The Outsiders      NaN
#
#                                                    Cast Country  \
# 6738  Dylan Kuo, Ady An, Lan Cheng-Lung, Michael Cha...  Taiwan
#
#         Release_Date Rating  Duration  \
# 6738  April 30, 2019  TV-MA  1 Season
#
#                                                    Type  \
# 6738  Crime TV Shows, International TV Shows, Romant...
#
#                                             Description
# 6738  A trio of delinquent brothers fends off neighb...

# %%
df[df['Title'].str.contains('The Outsiders')]
# Out:
#      Show_Id Category          Title Director  \
# 6738   s6737  TV Show  The Outsiders      NaN
#
#                                                    Cast Country  \
# 6738  Dylan Kuo, Ady An, Lan Cheng-Lung, Michael Cha...  Taiwan
#
#         Release_Date Rating  Duration  \
# 6738  April 30, 2019  TV-MA  1 Season
#
#                                                    Type  \
# 6738  Crime TV Shows, International TV Shows, Romant...
#
#                                             Description
# 6738  A trio of delinquent brothers fends off neighb...

# %% [markdown]
# # **In which year highest number & lowest no of the TV Show & Movies were released ? Show with Bar Graph.**

# %%
df['Date_N'] = pd.to_datetime(df['Release_Date'])#convert object data type in date format

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
df['Date_N'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %% [markdown]
# # **How many Movies & TV Shows are in the dataset ? Show with Bar Graph.**
#
# ---

# %%
df['Date_N'].dt.year.value_counts().plot(kind='bar')

# %%
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(df['Category'])        # To show the count of all unique values of any column in the form of bar graph
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # **Show all the Movies that were released in year 2000.**
#
# ---

# %%
# data['Year'] = data['Date_N'].dt.year           # to create new Year column ; it will consider only year

df['Year'] = df['Date_N'].dt.year

# %%
df[ (df['Category'] == 'Movie') & (df['Year']==2000) ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
df[ (df['Category'] == 'Movie') & (df['Year']==2020) ]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [markdown]
# Show all the Movies that were released in year 2020
# .

# %%
df[ (df['Category'] == 'Movie') & (df['Year']==2020) ]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [markdown]
# # **Show only the Titles of all TV Shows that were released in Japan only.**
#
# ---

# %%
df[ (df['Category']=='TV Show') & (df['Country']=='Japan') ] ['Title']
# Out:
# 24      ​SAINT SEIYA: Knights of the Zodiac
# 260                                A.I.C.O.
# 341                              Aggretsuko
# 348      Ainori Love Wagon: African Journey
# 349        Ainori Love Wagon: Asian Journey
#                        ...
# 7389                         Vampire Knight
# 7425                      Violet Evergarden
# 7742                      Your lie in April
# 7751                              Yu-Gi-Oh!
# 7777                             Zoids Wild
# Name: Title, Length: 157, dtype: object

# %% [markdown]
# # **Show Top 5 Directors, who gave the highest number of TV Shows & Movies to Netflix ?**
#
# ---

# %%
df['Director'].value_counts().head(5)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Name: Director, dtype: int64

# %% [markdown]
# # **Show all the Records, where "Category is Movie and Type is Horror" or "Country is India".**
#
# ---

# %%
df[ (df['Category']=='Movie') & (df['Type']=='Horror') ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
df[ (df['Category']=='Movie') & (df['Type']=='Horror') | (df['Country']=='India')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...

# %% [markdown]
# ### Q.8. In how many movies/shows, Anil kapoor was cast ?

# %%
df[df['Cast'] == 'Anil Kapoor']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
#df[df['Cast'].str.contains('Anil kapoor')]  .... [gives error as contains missing values]

# %% [markdown]
# # Creating new Df as old one contains missing values

# %%
df_new = df.dropna()

# %%
df_new[df_new['Cast'].str.contains('Anil Kapoor')]
# Out:
#      Show_Id Category                            Title  \
# 362     s363    Movie                         AK vs AK
# 866     s867    Movie                          Bewafaa
# 1758   s1759    Movie                  Dil Dhadakne Do
# 1939   s1940    Movie  Ek Ladki Ko Dekha Toh Aisa Laga
# 2588   s2589    Movie        Hamara Dil Aapke Paas Hai
# 2862   s2863    Movie           Humko Deewana Kar Gaye
# 3862   s3863    Movie                       Mahabharat
# 3884   s3885    Movie                           Malang
# 3912   s3913    Movie                             Mann
# 4264   s4265    Movie                        Mubarakan
# 4485   s4486    Movie                         No Entry
# 5001   s5001    Movie                            Pukar
# 5053   s5053    Movie                             Race
# 5054   s5054    Movie                           Race 2
# 5954   s5954    Movie                             Taal
# 6036   s6036    Movie                             Tezz
# ...

# %% [markdown]
# ### **What are the different Ratings defined by Netflix ?**

# %%
df['Rating'].nunique()
# Out:
# 14

# %%
df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # **How many Movies got the 'UR' rating, in France?**

# %%
df[(df['Category']=='Movie') & (df['Rating']=='UR')].shape
# Out:
# (5, 13)

# %%
df[(df['Category']=='Movie') & (df['Rating']=='UR') & (df['Country']=='France')].shape
# Out:
# (1, 13)

# %% [markdown]
# # **How many TV Show got the 'TV-MA' rating, after year 2019 ?**

# %%
df[(df['Category']=='TV Show') & (df['Rating']=='TV-MA')]
# Out:
#      Show_Id Category              Title              Director  \
# 0         s1  TV Show                 3%                   NaN
# 5         s6  TV Show                 46           Serdar Akar
# 11       s12  TV Show               1983                   NaN
# 12       s13  TV Show               1994  Diego Enrique Osorno
# 26       s27  TV Show           (Un)Well                   NaN
# ...      ...      ...                ...                   ...
# 7735   s7734  TV Show  You're My Destiny                   NaN
# 7740   s7739  TV Show    Young Wallander                   NaN
# 7754   s7753  TV Show      Yummy Mummies                   NaN
# 7757   s7756  TV Show           Z Nation                   NaN
# 7781   s7780  TV Show          Zona Rosa                   NaN
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# ...

# %%
df[(df['Category']=='TV Show') & (df['Rating']=='TV-MA') & (df['Year'] > 2019)]
# Out:
#      Show_Id Category                Title Director  \
# 0         s1  TV Show                   3%      NaN
# 26       s27  TV Show             (Un)Well      NaN
# 29       s30  TV Show             #blackAF      NaN
# 63       s64  TV Show       13 Reasons Why      NaN
# 85       s86  TV Show             21 Again      NaN
# ...      ...      ...                  ...      ...
# 7657   s7656  TV Show   Women Of The Night      NaN
# 7665   s7664  TV Show         Workin' Moms      NaN
# 7676   s7675  TV Show  Wrong Kind of Black      NaN
# 7727   s7726  TV Show      You Cannot Hide      NaN
# 7740   s7739  TV Show      Young Wallander      NaN
#
#                                                    Cast         Country  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 26                                                  NaN   United States
# 29    Kenya Barris, Rashida Jones, Iman Benson, Genn...   United States
# ...

# %% [markdown]
# # ** What is the maximum duration of a Movie/Show on Netflix ?**

# %%
df.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
df.Duration.dtypes
# Out:
# dtype('O')

# %%
df[['Minutes', 'Unit']] = df['Duration'].str.split(' ', expand = True)

# %%
df['Minutes'].max()
# Out:
# '99'

# %%
df['Minutes'].min()
# Out:
# '1'

# %%
df['Minutes'].mean()
# Out:
# inf

# %% [markdown]
# # **Q.11. Which individual country has the Highest No. of TV Shows ?**

# %%
df_tvshow = df[df['Category'] == 'TV Show']

# %%
df_tvshow.Country.value_counts()
# Out:
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: Country, Length: 183, dtype: int64

# %%
df_tvshow.Country.value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# # **How can we sort the dataset by Year ?**

# %%
df.sort_values(by = 'Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %%
df.sort_values(by = 'Year', ascending = False).head(10)
# Out:
#      Show_Id Category                                              Title  \
# 5564   s5564    Movie                                    Sherlock Holmes
# 5919   s5919    Movie                                          Surf's Up
# 980     s981  TV Show                                       Bling Empire
# 5955   s5955    Movie                                   Taare Zameen Par
# 366     s367    Movie                                          Al acecho
# 560     s561    Movie                                           Apaharan
# 1355   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 5922   s5922  TV Show                                    Surviving Death
# 4269   s4270    Movie                                                Mud
# 2799   s2800    Movie                                               Hook
#
#                      Director  \
# 5564              Guy Ritchie
# 5919  Ash Brannon, Chris Buck
# 980                       NaN
# 5955               Aamir Khan
# ...

# %% [markdown]
# # **Find all the instances where : Category is 'Movie' and Type is 'Dramas or Category is 'TV Show' & Type is 'Kids tv'**

# %%
# data [(data['Category']=='Movie') & (data['Type']=='Dramas') | (data['Category']=='TV Show') & (data['Type']=="Kids' TV")].head(1)

df[ (df['Category']=='Movie') & (df['Type']=='Dramas') | (df['Category']=='TV Show') & (df['Type']== "Kids' TV") ]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
